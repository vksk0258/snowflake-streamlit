# %%
import streamlit as st
import pandas as pd
import altair as alt

# %%
conn = st.connection("snowflake")

QUALIFIED_TABLE_NAME = "FROSTY_SAMPLE.CYBERSYN_FINANCIAL.FINANCIAL_ENTITY_ANNUAL_TIME_SERIES"
# Out:
# 2024-03-31 13:00:17.553
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
df = conn.query(f"SELECT * FROM {QUALIFIED_TABLE_NAME}")
# Out:
# 2024-03-31 13:01:23.296 No runtime found, using MemoryCacheStorageManager
# 2024-03-31 13:01:23.299 No runtime found, using MemoryCacheStorageManager

# %%
df
# Out:
#                      ENTITY_NAME         CITY STATE_ABBREVIATION
# 0            Bank of Gibson City  Gibson City                 IL  \
# 1            Bank of Gibson City  Gibson City                 IL
# 2            Bank of Gibson City  Gibson City                 IL
# 3            Bank of Gibson City  Gibson City                 IL
# 4            Bank of Gibson City  Gibson City                 IL
# ...                          ...          ...                ...
# 1043212  Itasca Bank & Trust Co.       Itasca                 IL
# 1043213  Itasca Bank & Trust Co.       Itasca                 IL
# 1043214  Itasca Bank & Trust Co.       Itasca                 IL
# 1043215  Itasca Bank & Trust Co.       Itasca                 IL
# 1043216  Itasca Bank & Trust Co.       Itasca                 IL
#
#                  VARIABLE_NAME  YEAR         VALUE     UNIT
# 0                 Total Assets  2007  6.168200e+07      USD  \
# 1               Total deposits  2007  5.143100e+07      USD
# 2        % Insured (Estimated)  2007  8.518382e-01  Percent
# 3        All Real Estate Loans  2007  1.543300e+07      USD
# 4             Total Securities  2007  2.371700e+07      USD
# ...                        ...   ...           ...      ...
# 1043212  % Insured (Estimated)  2020  7.098698e-01  Percent
# 1043213  All Real Estate Loans  2020  2.549730e+08      USD
# 1043214       Total Securities  2020  1.854260e+08      USD
# 1043215           Total Assets  2021  7.348250e+08      USD
# 1043216         Total deposits  2021  6.674140e+08      USD
#
#                                                 DEFINITION
# 0        The sum of all assets owned by the institution...
# 1        The sum of all deposits including demand depos...
# 2        Percent of deposits estimated to be insured.  ...
# 3        Loans secured primarily by real estate, whethe...
# 4        Total securities: the sum of held-to-maturity ...
# ...                                                    ...
# 1043212  Percent of deposits estimated to be insured.  ...
# 1043213  Loans secured primarily by real estate, whethe...
# 1043214  Total securities: the sum of held-to-maturity ...
# 1043215  The sum of all assets owned by the institution...
# 1043216  The sum of all deposits including demand depos...
#
# [1043217 rows x 8 columns]

# %%
df_total = df[df['VARIABLE_NAME'].str.contains('Total Assets')]
df_total
# Out:
#                              ENTITY_NAME         CITY STATE_ABBREVIATION
# 0                    Bank of Gibson City  Gibson City                 IL  \
# 5                    Bank of Gibson City  Gibson City                 IL
# 10       Terrabank, National Association        Miami                 FL
# 15       Terrabank, National Association        Miami                 FL
# 20               Blue Grass Savings Bank   Blue Grass                 IA
# ...                                  ...          ...                ...
# 1043199       Farmers and Merchants Bank    Maysville                 OK
# 1043204       Farmers and Merchants Bank    Maysville                 OK
# 1043209                     Peoples Bank      Clifton                 TN
# 1043210          Itasca Bank & Trust Co.       Itasca                 IL
# 1043215          Itasca Bank & Trust Co.       Itasca                 IL
#
#         VARIABLE_NAME  YEAR        VALUE UNIT
# 0        Total Assets  2007   61682000.0  USD  \
# 5        Total Assets  2008   66816000.0  USD
# 10       Total Assets  1998  109013000.0  USD
# 15       Total Assets  1999  136060000.0  USD
# 20       Total Assets  1997   88839000.0  USD
# ...               ...   ...          ...  ...
# 1043199  Total Assets  1986   20833000.0  USD
# 1043204  Total Assets  1987   45001000.0  USD
# 1043209  Total Assets  1994   37308000.0  USD
# 1043210  Total Assets  2020  692458000.0  USD
# 1043215  Total Assets  2021  734825000.0  USD
#
#                                                 DEFINITION
# 0        The sum of all assets owned by the institution...
# 5        The sum of all assets owned by the institution...
# 10       The sum of all assets owned by the institution...
# 15       The sum of all assets owned by the institution...
# 20       The sum of all assets owned by the institution...
# ...                                                    ...
# 1043199  The sum of all assets owned by the institution...
# 1043204  The sum of all assets owned by the institution...
# 1043209  The sum of all assets owned by the institution...
# 1043210  The sum of all assets owned by the institution...
# 1043215  The sum of all assets owned by the institution...
#
# [208644 rows x 8 columns]

# %%
filtered_df_city = df_total[df_total['CITY'] == 'Miami'].sort_values(by=['YEAR'], axis=0)
filtered_df_city
# Out:
#                                               ENTITY_NAME   CITY
# 867867                                  Orange State Bank  Miami  \
# 745074                    AmeriFirst Federal Savings Bank  Miami
# 975025                                         Ocean Bank  Miami
# 30577                   Newtek Bank, National Association  Miami
# 595677           Peoples National Bank of Commerce, Miami  Miami
# ...                                                   ...    ...
# 298499                         International Finance Bank  Miami
# 468664                              Pacific National Bank  Miami
# 724825  The First National Bank and Trust Company of M...  Miami
# 814511                                        Banesco USA  Miami
# 794052                  Newtek Bank, National Association  Miami
#
#        STATE_ABBREVIATION VARIABLE_NAME  YEAR         VALUE UNIT
# 867867                 FL  Total Assets  1984  9.376000e+06  USD  \
# 745074                 FL  Total Assets  1984  3.985690e+09  USD
# 975025                 FL  Total Assets  1984  2.504680e+08  USD
# 30577                  FL  Total Assets  1984  7.580900e+07  USD
# 595677                 FL  Total Assets  1984  1.772600e+07  USD
# ...                   ...           ...   ...           ...  ...
# 298499                 FL  Total Assets  2023  1.049917e+09  USD
# 468664                 FL  Total Assets  2023  1.216080e+09  USD
# 724825                 OK  Total Assets  2023  2.145590e+08  USD
# 814511                 FL  Total Assets  2023  3.808125e+09  USD
# 794052                 FL  Total Assets  2023  6.608880e+08  USD
#
#                                                DEFINITION
# 867867  The sum of all assets owned by the institution...
# 745074  The sum of all assets owned by the institution...
# 975025  The sum of all assets owned by the institution...
# 30577   The sum of all assets owned by the institution...
# 595677  The sum of all assets owned by the institution...
# ...                                                   ...
# 298499  The sum of all assets owned by the institution...
# 468664  The sum of all assets owned by the institution...
# 724825  The sum of all assets owned by the institution...
# 814511  The sum of all assets owned by the institution...
# 794052  The sum of all assets owned by the institution...
#
# [936 rows x 8 columns]

# %%
timeline_chart = alt.Chart( 
    df_total
    ).mark_area( 
        line={'color':'darkgreen'},
        interpolate='basis',
        color=alt.Gradient(
            gradient='linear',
            stops=[
                alt.GradientStop(color='white', offset=0),
                alt.GradientStop(color='darkgreen', offset=1)
                ],
            x1=1,
            x2=1,
            y1=1,
            y2=0
            )
    ).encode( # https://altair-viz.github.io/user_guide/encodings/index.html#encoding-data-types
        x=alt.X('YEAR', title=''),
        y=alt.Y('VALUE', title='구매 건 수')
    ).properties(
        height=300
    ).interactive()
    
timeline_chart
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\vegalite\v5\api.py:2975, in Chart.to_dict(self, validate, format, ignore, context)
#    2971     copy.data = core.InlineData(values=[{}])  # type: ignore[assignment]
#    2972     return super(Chart, copy).to_dict(
#    2973         validate=validate, format=format, ignore=ignore, context=context
#    2974     )
# -> 2975 return super().to_dict(
#    2976     validate=validate, format=format, ignore=ignore, context=context
#    2977 )
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\vegalite\v5\api.py:950, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#     948 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     949 original_data = getattr(copy, "data", Undefined)
# --> 950 copy.data = _prepare_data(original_data, context)
#     952 if original_data is not Undefined:
#     953     context["data"] = original_data
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\vegalite\v5\api.py:111, in _prepare_data(data, context)
#     109 # convert dataframes  or objects with __geo_interface__ to dict
#     110 elif isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# --> 111     data = _pipe(data, data_transformers.get())
#     113 # convert string input to a URLData
#     114 elif isinstance(data, str):
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\toolz\functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\toolz\functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\vegalite\data.py:23, in default_data_transformer(data, max_rows)
#      19 @curried.curry
#      20 def default_data_transformer(
#      21     data: DataType, max_rows: int = 5000
#      22 ) -> ToValuesReturnType:
# ---> 23     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\toolz\functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\toolz\functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\utils\data.py:117, in limit_rows(data, max_rows)
#     114     return pa_table
#     116 if max_rows is not None and len(values) > max_rows:
# --> 117     raise_max_rows_error()
#     119 return data
#
# File c:\Users\vksk0\anaconda3\envs\streamlit\Lib\site-packages\altair\utils\data.py:81, in limit_rows.<locals>.raise_max_rows_error()
#      80 def raise_max_rows_error():
# ---> 81     raise MaxRowsError(
#      82         "The number of rows in your dataset is greater "
#      83         f"than the maximum allowed ({max_rows}).\n\n"
#      84         "Try enabling the VegaFusion data transformer which "
#      85         "raises this limit by pre-evaluating data\n"
#      86         "transformations in Python.\n"
#      87         "    >> import altair as alt\n"
#      88         '    >> alt.data_transformers.enable("vegafusion")\n\n'
#      89         "Or, see https://altair-viz.github.io/user_guide/large_datasets.html "
#      90         "for additional information\n"
#      91         "on how to plot large datasets."
#      92     )
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000).
#
# Try enabling the VegaFusion data transformer which raises this limit by pre-evaluating data
# transformations in Python.
#     >> import altair as alt
#     >> alt.data_transformers.enable("vegafusion")
#
# Or, see https://altair-viz.github.io/user_guide/large_datasets.html for additional information
# on how to plot large datasets.
# alt.Chart(...)
